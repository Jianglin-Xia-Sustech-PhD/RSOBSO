# %% [markdown]
# 4 regimes - Weathers Portfolio Data Process

# %% [markdown]
# original data

# %% [markdown]
# regime 1: high GDP, high CPI

# %% [markdown]
# regime 2: high GDP, low CPI

# %% [markdown]
# regime 3: low GDP, high CPI

# %% [markdown]
# regime 4: low GDP, low CPI

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
# original dataset
# regime 1: high GDP, high CPI; regime 2: high GDP, low CPI; 
# regime 3: low GDP, high CPI; regime 4: low GDP, low CPI
df0 = pd.read_csv('weathers_state.csv')
df0['state_name'] = df0['state'].map({1: 'HGHC', 2: 'HGLC', 3: 'LGHC', 4: 'LGLC'})
df0
# Out:
#          Date  state state_name
# 0    19930201      4       LGLC
# 1    19930301      4       LGLC
# 2    19930401      1       HGHC
# 3    19930501      2       HGLC
# 4    19930601      4       LGLC
# ..        ...    ...        ...
# 310  20181201      2       HGLC
# 311  20190101      2       HGLC
# 312  20190201      4       LGLC
# 313  20190301      1       HGHC
# 314  20190401      3       LGHC
#
# [315 rows x 3 columns]

# %%
# to make the rate \lambda in increasing order (1/25, 1/5, 1, 5)
# and make state index as 0, 1, 2, 3 to keep the same with original synthetic data
df0['state'] = df0['state'].replace({2: 0, 4: 2})
df0
# Out:
#          Date  state state_name
# 0    19930201      2       LGLC
# 1    19930301      2       LGLC
# 2    19930401      1       HGHC
# 3    19930501      0       HGLC
# 4    19930601      2       LGLC
# ..        ...    ...        ...
# 310  20181201      0       HGLC
# 311  20190101      0       HGLC
# 312  20190201      2       LGLC
# 313  20190301      1       HGHC
# 314  20190401      3       LGHC
#
# [315 rows x 3 columns]

# %%
# given + upcoming: 200905-201704, 201705-201904 (96+24=120)
df_new = df0[(df0['Date'] >= 20090501) & (df0['Date'] < 20190501)].reset_index(drop=True)
df_new
# Out:
#          Date  state state_name
# 0    20090501      2       LGLC
# 1    20090601      2       LGLC
# 2    20090701      0       HGLC
# 3    20090801      1       HGHC
# 4    20090901      1       HGHC
# ..        ...    ...        ...
# 115  20181201      0       HGLC
# 116  20190101      0       HGLC
# 117  20190201      2       LGLC
# 118  20190301      1       HGHC
# 119  20190401      3       LGHC
#
# [120 rows x 3 columns]

# %%
counts = df_new['state'].value_counts().sort_index()
for state in range(4):
    print(f"State {state}: {counts.get(state, 0)} times")
# Out:
# State 0: 36 times
# State 1: 28 times
# State 2: 23 times
# State 3: 33 times

# %%
# 前96个
counts_first96 = df_new['state'].iloc[:96].value_counts().sort_index()
print("👉 前96个状态出现次数：")
for state in range(4):
    print(f"State {state}: {counts_first96.get(state, 0)} times")
# Out:
# 👉 前96个状态出现次数：
# State 0: 29 times
# State 1: 21 times
# State 2: 19 times
# State 3: 27 times

# %%
# 后24个
counts_last24 = df_new['state'].iloc[-24:].value_counts().sort_index()
print("\n👉 后24个状态出现次数：")
for state in range(4):
    print(f"State {state}: {counts_last24.get(state, 0)} times")
# Out:
# 👉 后24个状态出现次数：
# State 0: 7 times
# State 1: 7 times
# State 2: 4 times
# State 3: 6 times

# %%
S = df_new['state'].to_numpy()
rng = np.random.default_rng(seed=50)
xi = np.empty(len(S))
scale_map = {0: 30, 1: 18, 2: 12, 3: 1}
# regime 0: rate 1/30, regime 1: rate 1/18, regime 2: rate 1/12, regime 3: rate 1 (increasing rate lambda)
for i, s in enumerate(S):
    xi[i] = stats.expon(scale=scale_map[s]).rvs(random_state=rng)

df_new['xi'] = xi
df_new.groupby('state')['xi'].mean()
# Out:
# state
# 0    31.887967
# 1    13.074849
# 2     9.858685
# 3     0.727808
# Name: xi, dtype: float64

# %%
# given + upcoming: 200001-200712, 200801-200912 (96+24=120)
df_used = df0[(df0['Date'] >= 20000101) & (df0['Date'] < 20100101)].reset_index(drop=True)
df_used
# Out:
#          Date  state state_name
# 0    20000101      3       LGHC
# 1    20000201      3       LGHC
# 2    20000301      1       HGHC
# 3    20000401      0       HGLC
# 4    20000501      3       LGHC
# ..        ...    ...        ...
# 115  20090801      1       HGHC
# 116  20090901      1       HGHC
# 117  20091001      1       HGHC
# 118  20091101      3       LGHC
# 119  20091201      1       HGHC
#
# [120 rows x 3 columns]

# %%
S = df_used['state'].to_numpy()
S
# Out:
# array([3, 3, 1, 0, 3, 1, 2, 0, 3, 2, 2, 2, 1, 2, 2, 3, 1, 2, 0, 0, 2, 0,
#        2, 0, 0, 2, 1, 3, 2, 0, 1, 3, 0, 3, 1, 3, 3, 1, 3, 0, 0, 1, 2, 1,
#        1, 0, 0, 3, 3, 0, 1, 3, 1, 3, 0, 2, 2, 1, 3, 0, 0, 3, 3, 1, 2, 0,
#        3, 1, 3, 2, 0, 0, 3, 0, 0, 3, 1, 3, 2, 0, 0, 2, 1, 3, 2, 1, 3, 0,
#        3, 1, 2, 0, 3, 3, 3, 0, 1, 2, 0, 2, 1, 1, 3, 2, 2, 2, 2, 2, 0, 1,
#        2, 2, 2, 2, 0, 1, 1, 1, 3, 1])

# %%
counts = df_used['state'].value_counts().sort_index()
for state in range(4):
    print(f"State {state}: {counts.get(state, 0)} times")
# Out:
# State 0: 30 times
# State 1: 28 times
# State 2: 31 times
# State 3: 31 times

# %%
# 前96个
counts_first96 = df_used['state'].iloc[:96].value_counts().sort_index()
print("👉 前96个状态出现次数：")
for state in range(4):
    print(f"State {state}: {counts_first96.get(state, 0)} times")
# Out:
# 👉 前96个状态出现次数：
# State 0: 27 times
# State 1: 20 times
# State 2: 20 times
# State 3: 29 times

# %%
# 后24个
counts_last24 = df_used['state'].iloc[-24:].value_counts().sort_index()
print("\n👉 后24个状态出现次数：")
for state in range(4):
    print(f"State {state}: {counts_last24.get(state, 0)} times")
# Out:
# 👉 后24个状态出现次数：
# State 0: 3 times
# State 1: 8 times
# State 2: 11 times
# State 3: 2 times

# %%
# 设定随机种子，确保结果可重复
rng = np.random.default_rng(seed=40)

# 初始化 xi 数组
xi = np.empty(len(S))

scale_map = {0: 27, 1: 9, 2: 3, 3: 1}

# 遍历生成 xi
# regime 0: rate 1/25, regime 1: rate 1/5, regime 2: rate 1, regime 3: rate 5 (increasing rate lambda)
for i, s in enumerate(S):
    xi[i] = stats.expon(scale=scale_map[s]).rvs(random_state=rng)

# %%
df_used['xi'] = xi
df_used
# Out:
#          Date  state state_name         xi
# 0    20000101      3       LGHC   1.044443
# 1    20000201      3       LGHC   1.081783
# 2    20000301      1       HGHC  12.228168
# 3    20000401      0       HGLC   3.049605
# 4    20000501      3       LGHC   3.577926
# ..        ...    ...        ...        ...
# 115  20090801      1       HGHC   3.642819
# 116  20090901      1       HGHC  37.734735
# 117  20091001      1       HGHC   6.669465
# 118  20091101      3       LGHC   1.127751
# 119  20091201      1       HGHC   3.620809
#
# [120 rows x 4 columns]

# %%
df_used.head(50)
# Out:
#         Date  state state_name         xi
# 0   20000101      3       LGHC   1.044443
# 1   20000201      3       LGHC   1.081783
# 2   20000301      1       HGHC  12.228168
# 3   20000401      0       HGLC   3.049605
# 4   20000501      3       LGHC   3.577926
# 5   20000601      1       HGHC  57.621530
# 6   20000701      2       LGLC   5.207583
# 7   20000801      0       HGLC  10.934506
# 8   20000901      3       LGHC   0.414132
# 9   20001001      2       LGLC   4.766138
# 10  20001101      2       LGLC   0.319920
# 11  20001201      2       LGLC   0.242482
# 12  20010101      1       HGHC  10.624358
# 13  20010201      2       LGLC   0.364624
# 14  20010301      2       LGLC   0.630574
# 15  20010401      3       LGHC   0.770211
# 16  20010501      1       HGHC   4.727070
# 17  20010601      2       LGLC   4.377309
# 18  20010701      0       HGLC  13.069351
# 19  20010801      0       HGLC   8.221968
# 20  20010901      2       LGLC   1.129350
# 21  20011001      0       HGLC  18.507970
# 22  20011101      2       LGLC   0.868856
# 23  20011201      0       HGLC   0.935042
# 24  20020101      0       HGLC   8.019172
# 25  20020201      2       LGLC   1.401774
# 26  20020301      1       HGHC  11.265534
# 27  20020401      3       LGHC   1.166711
# 28  20020501      2       LGLC   1.137556
# 29  20020601      0       HGLC  53.520845
# 30  20020701      1       HGHC  15.945461
# 31  20020801      3       LGHC   0.347290
# 32  20020901      0       HGLC  21.771016
# 33  20021001      3       LGHC   0.393332
# 34  20021101      1       HGHC   2.156250
# 35  20021201      3       LGHC   0.408852
# 36  20030101      3       LGHC   1.556013
# 37  20030201      1       HGHC  11.077913
# 38  20030301      3       LGHC   0.176116
# 39  20030401      0       HGLC  45.671546
# 40  20030501      0       HGLC  17.738728
# 41  20030601      1       HGHC   5.678003
# 42  20030701      2       LGLC   2.090149
# 43  20030801      1       HGHC   1.629909
# 44  20030901      1       HGHC   3.072794
# 45  20031001      0       HGLC   4.980368
# 46  20031101      0       HGLC  53.019340
# 47  20031201      3       LGHC   0.752323
# 48  20040101      3       LGHC   0.354211
# 49  20040201      0       HGLC   4.705208

# %%
df_used.groupby('state')['xi'].mean()
# Out:
# state
# 0    27.699707
# 1    10.426432
# 2     2.996756
# 3     0.933353
# Name: xi, dtype: float64

# %%
# demand: decreasing order
# rate: increasing order
# satisfy the demand
